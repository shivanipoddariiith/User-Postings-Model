# %%
import pyLDAvis.gensim as gensimvis

# %%
import pyLDAvis

# %%
# %run data_analysis.py
# Out:
# Training LDA

# %%
ldamodel = models.ldamodel.LdaModel(corpus, num_topics = 10, id2word = dictionary, passes = 200)

# %%
ldamodel.save('user_postings.model')

# %%
from glob import glob
import re
import string
import funcy as fp
from gensim import models
from gensim.corpora import Dictionary, MmCorpus
import nltk
import pandas as pd

# %%
MmCorpus.serialize('user_data.mm', corpus)

# %%
dictionary.save('user.dict')

# %%
# %run data_analysis.py
# Out:
# Training LDA
# ...

# %%
import pyLDAvis.gensim as gensimvis
import pyLDAvis

# %%
vis_data = gensimvis.prepare(ldamodel, corpus, dictionary)

# %%
pyLDAvis.display(vis_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el3432946154677281524910489"></div>
# <script type="text/javascript">
#
# ...
